# %% [markdown]
# <a href="https://colab.research.google.com/github/mikelzarate/30_Categorizacion_de_Compras/blob/main/Pruebas_ocr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pytesseract pdf2image PyPDF2
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev

import pytesseract
from PIL import Image
import io
from pdf2image import convert_from_path
import os
import datetime
from PyPDF2 import PdfWriter, PdfReader

# Configurar la ruta a Tesseract OCR en Google Colab
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

def dividir_pdf_por_albaran(pdf_path, output_folder):
    # Crear carpeta de fecha
    fecha_actual = datetime.date.today().strftime("%Y-%m-%d")
    carpeta_fecha = os.path.join(output_folder, fecha_actual)
    os.makedirs(carpeta_fecha, exist_ok=True)

    # Convertir PDF a imágenes
    imagenes = convert_from_path(pdf_path)

    albaranes = {}
    paginas_albaran = []

    for i, imagen in enumerate(imagenes):
        texto = pytesseract.image_to_string(imagen, lang='spa')
        # Buscar número de albarán (ajusta según tu formato)
        if "Albarán nº:" in texto:
            numero_albaran = texto.split("Albarán nº:")[1].split()[0]
            if numero_albaran not in albaranes:
                albaranes[numero_albaran] = []
            albaranes[numero_albaran].append(i)

    # Crear PDFs individuales
    lector_pdf = PdfReader(pdf_path)
    for albaran, paginas in albaranes.items():
        escritor_pdf = PdfWriter()
        for pagina_num in paginas:
            escritor_pdf.add_page(lector_pdf.pages[pagina_num])
        ruta_guardado = os.path.join(carpeta_fecha, f"Albaran_{albaran}.pdf")
        with open(ruta_guardado, "wb") as archivo_salida:
            escritor_pdf.write(archivo_salida)

# Ejemplo de uso:
pdf_path = "/content/PDFs_divididos/Binder1.pdf"  # Ruta del PDF en Google Colab
output_folder = "/content/PDFs_divididos"  # Carpeta de salida en Google Colab
dividir_pdf_por_albaran(pdf_path, output_folder)
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 22 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 0s (22.2 MB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
import os
os.environ['TESSDATA_PREFIX'] = '/usr/share/tesseract-ocr/4.00/tessdata/'

import pytesseract
from PIL import Image
import io
from pdf2image import convert_from_path
import os
import datetime
from PyPDF2 import PdfWriter, PdfReader

# Configurar la ruta a Tesseract OCR en Google Colab
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

def dividir_pdf_por_albaran(pdf_path, output_folder):
    # Crear carpeta de fecha
    fecha_actual = datetime.date.today().strftime("%Y-%m-%d")
    carpeta_fecha = os.path.join(output_folder, fecha_actual)
    os.makedirs(carpeta_fecha, exist_ok=True)

    # Convertir PDF a imágenes
    imagenes = convert_from_path(pdf_path)

    albaranes = {}
    paginas_albaran = []

    for i, imagen in enumerate(imagenes):
        texto = pytesseract.image_to_string(imagen, lang='spa')
        # Buscar número de albarán (ajusta según tu formato)
        if "Nº Albarán:" in texto:
            numero_albaran = texto.split("Nº Albarán:")[1].split()[0]
            if numero_albaran not in albaranes:
                albaranes[numero_albaran] = []
            albaranes[numero_albaran].append(i)

    # Crear PDFs individuales
    lector_pdf = PdfReader(pdf_path)
    for albaran, paginas in albaranes.items():
        escritor_pdf = PdfWriter()
        for pagina_num in paginas:
            escritor_pdf.add_page(lector_pdf.pages[pagina_num])
        ruta_guardado = os.path.join(carpeta_fecha, f"Albaran_{albaran}.pdf")
        with open(ruta_guardado, "wb") as archivo_salida:
            escritor_pdf.write(archivo_salida)

# Ejemplo de uso:
pdf_path = "/content/PDFs_divididos/Binder1.pdf"  # Ruta del PDF en Google Colab
output_folder = "/content/PDFs_divididos"  # Carpeta de salida en Google Colab
dividir_pdf_por_albaran(pdf_path, output_folder)

# Crear un archivo zip de la carpeta y descargarlo
shutil.make_archive("PDFs_divididos", 'zip', carpeta_descarga)
files.download("PDFs_divididos.zip")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-6f5f3c1c7fe8> in <cell line: 0>()
#      50
#      51 # Crear un archivo zip de la carpeta y descargarlo
# ---> 52 shutil.make_archive("PDFs_divididos", 'zip', carpeta_descarga)
#      53 files.download("PDFs_divididos.zip")
#
# NameError: name 'shutil' is not defined

# %%
# !pip install pytesseract pdf2image PyPDF2
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev

import pytesseract
from PIL import Image
import io
from pdf2image import convert_from_path
import os
import datetime
from PyPDF2 import PdfWriter, PdfReader
import shutil # import the shutil module
from google.colab import files # import the files object from google.colab


# Configurar la ruta a Tesseract OCR en Google Colab
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

def dividir_pdf_por_albaran(pdf_path, output_folder):
    # Crear carpeta de fecha
    fecha_actual = datetime.date.today().strftime("%Y-%m-%d")
    carpeta_fecha = os.path.join(output_folder, fecha_actual)
    os.makedirs(carpeta_fecha, exist_ok=True)

    # Convertir PDF a imágenes
    imagenes = convert_from_path(pdf_path)

    albaranes = {}
    paginas_albaran = []

    for i, imagen in enumerate(imagenes):
        texto = pytesseract.image_to_string(imagen, lang='spa')
        # Buscar número de albarán (ajusta según tu formato)
        if "Nº Albarán:" in texto:
            numero_albaran = texto.split("Nº Albarán:")[1].split()[0]
            if numero_albaran not in albaranes:
                albaranes[numero_albaran] = []
            albaranes[numero_albaran].append(i)

    # Crear PDFs individuales
    lector_pdf = PdfReader(pdf_path)
    for albaran, paginas in albaranes.items():
        escritor_pdf = PdfWriter()
        for pagina_num in paginas:
            escritor_pdf.add_page(lector_pdf.pages[pagina_num])
        ruta_guardado = os.path.join(carpeta_fecha, f"Albaran_{albaran}.pdf")
        with open(ruta_guardado, "wb") as archivo_salida:
            escritor_pdf.write(archivo_salida)

# Ejemplo de uso:
pdf_path = "/content/PDFs_divididos/Binder1.pdf"  # Ruta del PDF en Google Colab
output_folder = "/content/PDFs_divididos"  # Carpeta de salida en Google Colab
dividir_pdf_por_albaran(pdf_path, output_folder)

# Crear un archivo zip de la carpeta y descargarlo
# Assuming 'carpeta_descarga' should be 'carpeta_fecha'
# since 'carpeta_descarga' is not defined.
shutil.make_archive("PDFs_divididos", 'zip', output_folder, fecha_actual)
files.download("PDFs_divididos.zip")
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-929ea58d4f51> in <cell line: 0>()
#      56 # Assuming 'carpeta_descarga' should be 'carpeta_fecha'
#      57 # since 'carpeta_descarga' is not defined.
# ---> 58 shutil.make_archive("PDFs_divididos", 'zip', output_folder, fecha_actual)
#      59 files.download("PDFs_divididos.zip")
#
# NameError: name 'fecha_actual' is not defined

# %%
# !pip install pytesseract pdf2image PyPDF2
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev

import pytesseract
from PIL import Image
import io
from pdf2image import convert_from_path
import os
import datetime
from PyPDF2 import PdfWriter, PdfReader
import shutil # import the shutil module
from google.colab import files # import the files object from google.colab


# Configurar la ruta a Tesseract OCR en Google Colab
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

def dividir_pdf_por_albaran(pdf_path, output_folder):
    # Crear carpeta de fecha
    fecha_actual = datetime.date.today().strftime("%Y-%m-%d")
    carpeta_fecha = os.path.join(output_folder, fecha_actual)
    os.makedirs(carpeta_fecha, exist_ok=True)

    # Convertir PDF a imágenes
    imagenes = convert_from_path(pdf_path)

    albaranes = {}
    paginas_albaran = []

    for i, imagen in enumerate(imagenes):
        texto = pytesseract.image_to_string(imagen, lang='spa')
        # Buscar número de albarán (ajusta según tu formato)
        if "Nº Albarán:" in texto:
            numero_albaran = texto.split("Nº Albarán:")[1].split()[0]
            if numero_albaran not in albaranes:
                albaranes[numero_albaran] = []
            albaranes[numero_albaran].append(i)

    # Crear PDFs individuales
    lector_pdf = PdfReader(pdf_path)
    for albaran, paginas in albaranes.items():
        escritor_pdf = PdfWriter()
        for pagina_num in paginas:
            escritor_pdf.add_page(lector_pdf.pages[pagina_num])
        ruta_guardado = os.path.join(carpeta_fecha, f"Albaran_{albaran}.pdf")
        with open(ruta_guardado, "wb") as archivo_salida:
            escritor_pdf.write(archivo_salida)
    # Return carpeta_fecha to be used outside the function
    return carpeta_fecha


# Ejemplo de uso:
pdf_path = "/content/PDFs_divididos/Binder1.pdf"  # Ruta del PDF en Google Colab
output_folder = "/content/PDFs_divididos"  # Carpeta de salida en Google Colab
# Get the value of carpeta_fecha by calling the function
carpeta_fecha = dividir_pdf_por_albaran(pdf_path, output_folder)

# Crear un archivo zip de la carpeta y descargarlo
# Use carpeta_fecha, which is now available outside the function
shutil.make_archive("PDFs_divididos", 'zip', output_folder)
files.download("PDFs_divididos.zip")
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.

# %%
# !pip install pytesseract pdf2image PyPDF2
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev

import pytesseract
from PIL import Image
import io
from pdf2image import convert_from_path
import os
import datetime
from PyPDF2 import PdfWriter, PdfReader
import shutil # import the shutil module
from google.colab import files # import the files object from google.colab


# Configurar la ruta a Tesseract OCR en Google Colab
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

def dividir_pdf_por_albaran(pdf_path, output_folder):
    # Crear carpeta de fecha
    fecha_actual = datetime.date.today().strftime("%Y-%m-%d")
    carpeta_fecha = os.path.join(output_folder, fecha_actual)
    os.makedirs(carpeta_fecha, exist_ok=True)

    # Convertir PDF a imágenes
    imagenes = convert_from_path(pdf_path)

    albaranes = {}
    paginas_albaran = []

    for i, imagen in enumerate(imagenes):
        texto = pytesseract.image_to_string(imagen, lang='spa')

        # Improved Albarán Number Extraction
        # This regex will try to find patterns like "Nº Albarán: 12345"
        # or "Albarán nº:12345" or even "Albaran 12345" with some flexibility.
        import re
        match = re.search(r"(?:Nº Albarán:|Albarán nº:|Albaran)\s*(\d+)", texto)
        if match:
            numero_albaran = match.group(1)
            if numero_albaran not in albaranes:
                albaranes[numero_albaran] = []
            albaranes[numero_albaran].append(i)
        else:
            # Print the page text to help debug if albarán number is not found
            print(f"Albarán number not found on page {i + 1}. Page text:")
            print(texto)
            print("-" * 20)

    # Crear PDFs individuales
    lector_pdf = PdfReader(pdf_path)
    for albaran, paginas in albaranes.items():
        escritor_pdf = PdfWriter()
        for pagina_num in paginas:
            escritor_pdf.add_page(lector_pdf.pages[pagina_num])
        ruta_guardado = os.path.join(carpeta_fecha, f"Albaran_{albaran}.pdf")
        with open(ruta_guardado, "wb") as archivo_salida:
            escritor_pdf.write(archivo_salida)
    # Return carpeta_fecha to be used outside the function
    return carpeta_fecha


# Ejemplo de uso:
pdf_path = "/content/PDFs_divididos/Binder1.pdf"  # Ruta del PDF en Google Colab
output_folder = "/content/PDFs_divididos"  # Carpeta de salida en Google Colab
# Get the value of carpeta_fecha by calling the function
carpeta_fecha = dividir_pdf_por_albaran(pdf_path, output_folder)

# Crear un archivo zip de la carpeta y descargarlo
# Use carpeta_fecha, which is now available outside the function
shutil.make_archive("PDFs_divididos", 'zip', carpeta_fecha)
files.download("PDFs_divididos.zip")
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Albarán number not found on page 1. Page text:
#
#
# ALBARÁN DE VENTA
#
#
#
#
#
#
#
#
#
#
#
#
# Parque Tec. Bizkaia Edif 208
# 48170 ZAMUDIO
# 900 900 942
#
# pedidosOproquinorte.com CIMALabs - Citometría
#
# Goretti Azparren Larraya
#
# C/Fuente del hierro SN. Ed.CIMA 12 pl. Lab.1.07
# 31008 PAMPLONA
#
# “Pamplona
#
# CIF: R3168001J
#
# www.proquinorte.com
# CIF: A48202451
#
# N? bultos: 1. Peso: 2kg
#
# presa alkerán Ala atención de: Goretti Azparren Larraya
#
# N2 Albarán: V-ALB167361 5 Teléfono: 948194700
# ...

# %%
# !pip install pytesseract pdf2image PyPDF2
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev

import pytesseract
from PIL import Image
import io
from pdf2image import convert_from_path
import os
import datetime
from PyPDF2 import PdfWriter, PdfReader
import shutil # import the shutil module
from google.colab import files # import the files object from google.colab


# Configurar la ruta a Tesseract OCR en Google Colab
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

def dividir_pdf_por_albaran(pdf_path, output_folder):
    # Crear carpeta de fecha
    fecha_actual = datetime.date.today().strftime("%Y-%m-%d")
    carpeta_fecha = os.path.join(output_folder, fecha_actual)
    os.makedirs(carpeta_fecha, exist_ok=True)

    # Convertir PDF a imágenes
    imagenes = convert_from_path(pdf_path)

    albaranes = {}
    paginas_albaran = []

    for i, imagen in enumerate(imagenes):
        texto = pytesseract.image_to_string(imagen, lang='spa')

        # Improved Albarán Number Extraction with Handling for "Nº" Misinterpretation
        # This regex handles "N°", "Nº", "N2", "NS", "Albarán nº:", "Albaran"
        import re
        match = re.search(r"(?:N(?:º|°|2|S) Albarán:|Albarán n(?:º|°|2|S):|Albaran)\s*(\d+)", texto)
        if match:
            numero_albaran = match.group(1)
            if numero_albaran not in albaranes:
                albaranes[numero_albaran] = []
            albaranes[numero_albaran].append(i)
        else:
            # Print the page text to help debug if albarán number is not found
            print(f"Albarán number not found on page {i + 1}. Page text:")
            print(texto)
            print("-" * 20)

    # Crear PDFs individuales
    lector_pdf = PdfReader(pdf_path)
    for albaran, paginas in albaranes.items():
        escritor_pdf = PdfWriter()
        for pagina_num in paginas:
            escritor_pdf.add_page(lector_pdf.pages[pagina_num])
        ruta_guardado = os.path.join(carpeta_fecha, f"Albaran_{albaran}.pdf")
        with open(ruta_guardado, "wb") as archivo_salida:
            escritor_pdf.write(archivo_salida)
    # Return carpeta_fecha to be used outside the function
    return carpeta_fecha


# Ejemplo de uso:
pdf_path = "/content/PDFs_divididos/Binder1.pdf"  # Ruta del PDF en Google Colab
output_folder = "/content/PDFs_divididos"  # Carpeta de salida en Google Colab
# Get the value of carpeta_fecha by calling the function
carpeta_fecha = dividir_pdf_por_albaran(pdf_path, output_folder)

# Crear un archivo zip de la carpeta y descargarlo
# Use carpeta_fecha, which is now available outside the function
shutil.make_archive("PDFs_divididos", 'zip', carpeta_fecha)
files.download("PDFs_divididos.zip")
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Albarán number not found on page 1. Page text:
#
#
# ALBARÁN DE VENTA
#
#
#
#
#
#
#
#
#
#
#
#
# Parque Tec. Bizkaia Edif 208
# 48170 ZAMUDIO
# 900 900 942
#
# pedidosOproquinorte.com CIMALabs - Citometría
#
# Goretti Azparren Larraya
#
# C/Fuente del hierro SN. Ed.CIMA 12 pl. Lab.1.07
# 31008 PAMPLONA
#
# “Pamplona
#
# CIF: R3168001J
#
# www.proquinorte.com
# CIF: A48202451
#
# N? bultos: 1. Peso: 2kg
#
# presa alkerán Ala atención de: Goretti Azparren Larraya
#
# N2 Albarán: V-ALB167361 5 Teléfono: 948194700
# ...

# %%
# !pip install pytesseract pdf2image PyPDF2
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev

import pytesseract
from PIL import Image, ImageEnhance # Import ImageEnhance for contrast adjustment
import io
from pdf2image import convert_from_path
import os
import datetime
from PyPDF2 import PdfWriter, PdfReader
import shutil # import the shutil module
from google.colab import files # import the files object from google.colab


# Configurar la ruta a Tesseract OCR en Google Colab
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

def dividir_pdf_por_albaran(pdf_path, output_folder):
    # Crear carpeta de fecha
    fecha_actual = datetime.date.today().strftime("%Y-%m-%d")
    carpeta_fecha = os.path.join(output_folder, fecha_actual)
    os.makedirs(carpeta_fecha, exist_ok=True)

    # Convertir PDF a imágenes
    imagenes = convert_from_path(pdf_path)

    albaranes = {}
    paginas_albaran = []

    for i, imagen in enumerate(imagenes):
        # Image Preprocessing (Enhance Contrast)
        enhancer = ImageEnhance.Contrast(imagen)
        imagen_enhanced = enhancer.enhance(2.0)  # Adjust the factor as needed

        # OCR with PSM option
        texto = pytesseract.image_to_string(imagen_enhanced, lang='spa', config='--psm 6') # Experiment with different PSM values

        # Improved Albarán Number Extraction
        import re
        match = re.search(r"(?:N(?:º|°|2|S) Albarán:|Albarán n(?:º|°|2|S):|Albaran)\s*(\d+)", texto)
        if match:
            numero_albaran = match.group(1)
            if numero_albaran not in albaranes:
                albaranes[numero_albaran] = []
            albaranes[numero_albaran].append(i)
        else:
            # Print page text for debugging
            print(f"Albarán number not found on page {i + 1}. Page text:")
            print(texto)
            print("-" * 20)

    # Crear PDFs individuales
    lector_pdf = PdfReader(pdf_path)
    for albaran, paginas in albaranes.items():
        escritor_pdf = PdfWriter()
        for pagina_num in paginas:
            escritor_pdf.add_page(lector_pdf.pages[pagina_num])
        ruta_guardado = os.path.join(carpeta_fecha, f"Albaran_{albaran}.pdf")
        with open(ruta_guardado, "wb") as archivo_salida:
            escritor_pdf.write(archivo_salida)
    # Return carpeta_fecha to be used outside the function
    return carpeta_fecha


# Ejemplo de uso:
pdf_path = "/content/PDFs_divididos/Binder1.pdf"  # Ruta del PDF en Google Colab
output_folder = "/content/PDFs_divididos"  # Carpeta de salida en Google Colab
# Get the value of carpeta_fecha by calling the function
carpeta_fecha = dividir_pdf_por_albaran(pdf_path, output_folder)

# Crear un archivo zip de la carpeta y descargarlo
# Use carpeta_fecha, which is now available outside the function
shutil.make_archive("PDFs_divididos", 'zip', carpeta_fecha)
files.download("PDFs_divididos.zip")
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Albarán number not found on page 1. Page text:
# m
# (Hp rocunorre _ (GA
# > > ss > sos S6S
# ALBARÁN DE VENTA
# Parque Tec. Bizkaia Edif 208 z a
# XA
# 48170 ZAMUDIO ES 5
# 900 900 942 234
# 4 > - Ci
# pedidosOproquinorte.com oe %% FA babs Citometría
# www.proquinorte.com AN y $ e Goretti eaparien Larraya
# Ds: > S O C/Fuente del hierro SN. Ed.CIMA 12 pl. Lab.1.07
# CIF: A48202451 e, % A
# A eS 31008 PAMPLONA
# Tos ÁS “Pamplona
# N? bultos: 1. Peso: 2k
# 9 e Y CIF: R3168001)
# Sat
# Y Se e." s
# | rán E ;
# ...

# %%
# !pip install pytesseract pdf2image PyPDF2
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev

import pytesseract
from PIL import Image, ImageEnhance # Import ImageEnhance for contrast adjustment
import io
from pdf2image import convert_from_path
import os
import datetime
from PyPDF2 import PdfWriter, PdfReader
import shutil # import the shutil module
from google.colab import files # import the files object from google.colab


# Configurar la ruta a Tesseract OCR en Google Colab
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

def dividir_pdf_por_albaran(pdf_path, output_folder):
    # Crear carpeta de fecha
    fecha_actual = datetime.date.today().strftime("%Y-%m-%d")
    carpeta_fecha = os.path.join(output_folder, fecha_actual)
    os.makedirs(carpeta_fecha, exist_ok=True)

    # Convertir PDF a imágenes
    imagenes = convert_from_path(pdf_path)

    albaranes = {}
    paginas_albaran = []

    for i, imagen in enumerate(imagenes):
        # Image Preprocessing (Enhance Contrast)
        enhancer = ImageEnhance.Contrast(imagen)
        imagen_enhanced = enhancer.enhance(2.0)  # Adjust the factor as needed

        # OCR with PSM option
        texto = pytesseract.image_to_string(imagen_enhanced, lang='spa', config='--psm 6') # Experiment with different PSM values

        # Improved Albarán Number Extraction with Handling for "Nº" Misinterpretation
        # This regex handles "N°", "Nº", "N2", "NS", "Albarán nº:", "Albaran", "N?", "Ne"
        import re
        match = re.search(r"(?:N(?:º|°|2|S|\?|e) Albarán:|Albarán n(?:º|°|2|S|\?|e):|Albaran)\s*(\d+)", texto)
        if match:
            numero_albaran = match.group(1)
            if numero_albaran not in albaranes:
                albaranes[numero_albaran] = []
            albaranes[numero_albaran].append(i)
        else:
            # Print page text for debugging
            print(f"Albarán number not found on page {i + 1}. Page text:")
            print(texto)
            print("-" * 20)

    # Crear PDFs individuales
    lector_pdf = PdfReader(pdf_path)
    for albaran, paginas in albaranes.items():
        escritor_pdf = PdfWriter()
        for pagina_num in paginas:
            escritor_pdf.add_page(lector_pdf.pages[pagina_num])
        ruta_guardado = os.path.join(carpeta_fecha, f"Albaran_{albaran}.pdf")
        with open(ruta_guardado, "wb") as archivo_salida:
            escritor_pdf.write(archivo_salida)
    # Return carpeta_fecha to be used outside the function
    print(f"Albaranes found: {albaranes}")
    print(f"Output directory: {carpeta_fecha}")
    print(f"PDF file exists: {os.path.exists(pdf_path)}")
    return carpeta_fecha


# Ejemplo de uso:
pdf_path = "/content/PDFs_divididos/Binder1.pdf"  # Ruta del PDF en Google Colab
output_folder = "/content/PDFs_divididos"  # Carpeta de salida en Google Colab
# Get the value of carpeta_fecha by calling the function
carpeta_fecha = dividir_pdf_por_albaran(pdf_path, output_folder)

# Crear un archivo zip de la carpeta y descargarlo
# Use carpeta_fecha, which is now available outside the function
shutil.make_archive("PDFs_divididos", 'zip', carpeta_fecha)
files.download("PDFs_divididos.zip")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.8 MB/s eta 0:00:00
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 22 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 0s (11.6 MB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
# !apt-get install poppler-utils # Install poppler-utils, which includes pdfinfo
# !pip install pytesseract pdf2image PyPDF2
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev

import pytesseract
from PIL import Image, ImageEnhance # Import ImageEnhance for contrast adjustment
import io
from pdf2image import convert_from_path
import os
import datetime
from PyPDF2 import PdfWriter, PdfReader
import shutil # import the shutil module
from google.colab import files # import the files object from google.colab


# Configurar la ruta a Tesseract OCR en Google Colab
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

def dividir_pdf_por_albaran(pdf_path, output_folder):
    # Crear carpeta de fecha
    fecha_actual = datetime.date.today().strftime("%Y-%m-%d")
    carpeta_fecha = os.path.join(output_folder, fecha_actual)
    os.makedirs(carpeta_fecha, exist_ok=True)

    # Convertir PDF a imágenes
    imagenes = convert_from_path(pdf_path)

    albaranes = {}
    paginas_albaran = []

    for i, imagen in enumerate(imagenes):
        # Image Preprocessing (Enhance Contrast)
        enhancer = ImageEnhance.Contrast(imagen)
        imagen_enhanced = enhancer.enhance(2.0)  # Adjust the factor as needed

        # OCR with PSM option
        texto = pytesseract.image_to_string(imagen_enhanced, lang='spa', config='--psm 6') # Experiment with different PSM values

        # Improved Albarán Number Extraction with Handling for "Nº" Misinterpretation
        # This regex handles "N°", "Nº", "N2", "NS", "Albarán nº:", "Albaran", "N?", "Ne"
        import re
        match = re.search(r"(?:N(?:º|°|2|S|\?|e) Albarán:|Albarán n(?:º|°|2|S|\?|e):|Albaran)\s*(\d+)", texto)
        if match:
            numero_albaran = match.group(1)
            if numero_albaran not in albaranes:
                albaranes[numero_albaran] = []
            albaranes[numero_albaran].append(i)
        else:
            # Print page text for debugging
            print(f"Albarán number not found on page {i + 1}. Page text:")
            print(texto)
            print("-" * 20)

    # Crear PDFs individuales
    lector_pdf = PdfReader(pdf_path)
    for albaran, paginas in albaranes.items():
        escritor_pdf = PdfWriter()
        for pagina_num in paginas:
            escritor_pdf.add_page(lector_pdf.pages[pagina_num])
        ruta_guardado = os.path.join(carpeta_fecha, f"Albaran_{albaran}.pdf")
        with open(ruta_guardado, "wb") as archivo_salida:
            escritor_pdf.write(archivo_salida)
    # Return carpeta_fecha to be used outside the function
    print(f"Albaranes found: {albaranes}")
    print(f"Output directory: {carpeta_fecha}")
    print(f"PDF file exists: {os.path.exists(pdf_path)}")
    return carpeta_fecha


# Ejemplo de uso:
pdf_path = "/content/PDFs_divididos/Binder1.pdf"  # Ruta del PDF en Google Colab
output_folder = "/content/PDFs_divididos"  # Carpeta de salida en Google Colab
# Get the value of carpeta_fecha by calling the function
carpeta_fecha = dividir_pdf_por_albaran(pdf_path, output_folder)

# Crear un archivo zip de la carpeta y descargarlo
# Use carpeta_fecha, which is now available outside the function
shutil.make_archive("PDFs_divididos", 'zip', carpeta_fecha)
files.download("PDFs_divididos.zip")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 22 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 696 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.6 [186 kB]
# Fetched 186 kB in 0s (992 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 125115 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.6_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.6) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.6) ...
# Processing triggers for man-db (2.10.2-1) ...
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ...

# %%
# !apt-get install poppler-utils # Install poppler-utils, which includes pdfinfo
# !pip install pytesseract pdf2image PyPDF2
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev
# !sudo apt install tesseract-ocr-spa # Install Spanish language data

import pytesseract
from PIL import Image, ImageEnhance # Import ImageEnhance for contrast adjustment
import io
from pdf2image import convert_from_path
import os
import datetime
from PyPDF2 import PdfWriter, PdfReader
import shutil # import the shutil module
from google.colab import files # import the files object from google.colab


# Configurar la ruta a Tesseract OCR en Google Colab
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

def dividir_pdf_por_albaran(pdf_path, output_folder):
    # Crear carpeta de fecha
    fecha_actual = datetime.date.today().strftime("%Y-%m-%d")
    carpeta_fecha = os.path.join(output_folder, fecha_actual)
    os.makedirs(carpeta_fecha, exist_ok=True)

    # Convertir PDF a imágenes
    imagenes = convert_from_path(pdf_path)

    albaranes = {}
    paginas_albaran = []

    for i, imagen in enumerate(imagenes):
        # Image Preprocessing (Enhance Contrast)
        enhancer = ImageEnhance.Contrast(imagen)
        imagen_enhanced = enhancer.enhance(2.0)  # Adjust the factor as needed

        # OCR with PSM option
        texto = pytesseract.image_to_string(imagen_enhanced, lang='spa', config='--psm 6') # Experiment with different PSM values

        # Improved Albarán Number Extraction with Handling for "Nº" Misinterpretation
        # This regex handles "N°", "Nº", "N2", "NS", "Albarán nº:", "Albaran", "N?", "Ne"
        import re
        match = re.search(r"(?:N(?:º|°|2|S|\?|e) Albarán:|Albarán n(?:º|°|2|S|\?|e):|Albaran)\s*(\d+)", texto)
        if match:
            numero_albaran = match.group(1)
            if numero_albaran not in albaranes:
                albaranes[numero_albaran] = []
            albaranes[numero_albaran].append(i)
        else:
            # Print page text for debugging
            print(f"Albarán number not found on page {i + 1}. Page text:")
            print(texto)
            print("-" * 20)

    # Crear PDFs individuales
    lector_pdf = PdfReader(pdf_path)
    for albaran, paginas in albaranes.items():
        escritor_pdf = PdfWriter()
        for pagina_num in paginas:
            escritor_pdf.add_page(lector_pdf.pages[pagina_num])
        ruta_guardado = os.path.join(carpeta_fecha, f"Albaran_{albaran}.pdf")
        with open(ruta_guardado, "wb") as archivo_salida:
            escritor_pdf.write(archivo_salida)
    # Return carpeta_fecha to be used outside the function
    print(f"Albaranes found: {albaranes}")
    print(f"Output directory: {carpeta_fecha}")
    print(f"PDF file exists: {os.path.exists(pdf_path)}")
    return carpeta_fecha


# Ejemplo de uso:
pdf_path = "/content/PDFs_divididos/Binder1.pdf"  # Ruta del PDF en Google Colab
output_folder = "/content/PDFs_divididos"  # Carpeta de salida en Google Colab
# Get the value of carpeta_fecha by calling the function
carpeta_fecha = dividir_pdf_por_albaran(pdf_path, output_folder)

# Crear un archivo zip de la carpeta y descargarlo
# Use carpeta_fecha, which is now available outside the function
shutil.make_archive("PDFs_divididos", 'zip', carpeta_fecha)
files.download("PDFs_divididos.zip")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.6).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tesseract-ocr-spa
# 0 upgraded, 1 newly installed, 0 to remove and 22 not upgraded.
# Need to get 951 kB of archives.
# ...

# %%
# !apt-get install poppler-utils # Install poppler-utils, which includes pdfinfo
# !pip install pytesseract pdf2image PyPDF2
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev
# !sudo apt install tesseract-ocr-spa # Install Spanish language data

import pytesseract
from PIL import Image, ImageEnhance # Import ImageEnhance for contrast adjustment
import io
from pdf2image import convert_from_path
import os
import datetime
import re # Import re module here
from PyPDF2 import PdfWriter, PdfReader
import shutil # import the shutil module
from google.colab import files # import the files object from google.colab


# Configurar la ruta a Tesseract OCR en Google Colab
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

def dividir_pdf_por_albaran(pdf_path, output_folder):
    # Convertir PDF a imágenes
    imagenes = convert_from_path(pdf_path)

    albaranes = {}
    paginas_albaran = []
    fecha_registro = None  # Variable to store the extracted date

    for i, imagen in enumerate(imagenes):
        # Image Preprocessing (Enhance Contrast)
        enhancer = ImageEnhance.Contrast(imagen)
        imagen_enhanced = enhancer.enhance(2.0)  # Adjust the factor as needed

        # OCR with PSM option
        texto = pytesseract.image_to_string(imagen_enhanced, lang='spa', config='--psm 6') # Experiment with different PSM values

        # 1. Extract Albarán Number (V-ALB167464 format, max 11 chars)
        match_albaran = re.search(r"(V-ALB\d{6})", texto)
        if match_albaran:
            numero_albaran = match_albaran.group(1)
            if numero_albaran not in albaranes:
                albaranes[numero_albaran] = []
            albaranes[numero_albaran].append(i)

        # 2. Extract Fecha Registro (31/01/2025 format) and convert to 31-01-2025
        if fecha_registro is None:  # Only extract date once
            match_fecha = re.search(r"(\d{2}/\d{2}/\d{4})", texto)
            if match_fecha:
                fecha_registro = match_fecha.group(1).replace("/", "-")

    # Create output folder if it doesn't exist using extracted date
    carpeta_fecha = os.path.join(output_folder, fecha_registro)
    os.makedirs(carpeta_fecha, exist_ok=True)

    # Create individual PDFs
    lector_pdf = PdfReader(pdf_path)
    for albaran, paginas in albaranes.items():
        escritor_pdf = PdfWriter()
        for pagina_num in paginas:
            escritor_pdf.add_page(lector_pdf.pages[pagina_num])
        ruta_guardado = os.path.join(carpeta_fecha, f"{albaran}.pdf")
        with open(ruta_guardado, "wb") as archivo_salida:
            escritor_pdf.write(archivo_salida)

    print(f"Albaranes found: {albaranes}")
    print(f"Output directory: {carpeta_fecha}")
    print(f"PDF file exists: {os.path.exists(pdf_path)}")
    return carpeta_fecha


# Ejemplo de uso:
pdf_path = "/content/PDFs_divididos/Binder2.pdf"  # Ruta del PDF en Google Colab
output_folder = "/content/PDFs_divididos"  # Carpeta de salida en Google Colab
# Get the value of carpeta_fecha by calling the function
carpeta_fecha = dividir_pdf_por_albaran(pdf_path, output_folder)

# Crear un archivo zip de la carpeta y descargarlo
# Use carpeta_fecha, which is now available outside the function
shutil.make_archive("PDFs_divididos", 'zip', carpeta_fecha)
files.download("PDFs_divididos.zip")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.6).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-spa is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# ...

# %% [markdown]
# Apartir de aqui, cambiarlo a local

# %%
# !apt-get install poppler-utils # Install poppler-utils, which includes pdfinfo
# !pip install pytesseract pdf2image PyPDF2
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev
# !sudo apt install tesseract-ocr-spa # Install Spanish language data

import pytesseract
from PIL import Image, ImageEnhance # Import ImageEnhance for contrast adjustment
import io
from pdf2image import convert_from_path
import os
import datetime
import re # Import re module here
from PyPDF2 import PdfWriter, PdfReader
import shutil # import the shutil module
from google.colab import files # import the files object from google.colab


# Configurar la ruta a Tesseract OCR en Google Colab
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

def dividir_pdf_por_albaran(pdf_path, output_folder):
    # Convertir PDF a imágenes
    imagenes = convert_from_path(pdf_path)

    albaranes = {}

    for i, imagen in enumerate(imagenes):
        # ... (código para preprocesamiento de imagen y OCR)...

        # 1. Extraer el número de Albarán y la Fecha Registro
        match_albaran = re.search(r"(V-ALB\d{6})", texto)
        match_fecha = re.search(r"(\d{2}/\d{2}/\d{4})", texto)

        if match_albaran and match_fecha:
            numero_albaran = match_albaran.group(1)
            fecha_registro = match_fecha.group(1).replace("/", "-")

            # Almacenar el número de Albarán y la fecha de registro
            if numero_albaran not in albaranes:
                albaranes[numero_albaran] = {"fecha_registro": fecha_registro, "paginas": []}
            albaranes[numero_albaran]["paginas"].append(i)

    # Crear PDFs individuales en carpetas separadas por fecha
    lector_pdf = PdfReader(pdf_path)
    for albaran, datos in albaranes.items():
        fecha_carpeta = datos["fecha_registro"]
        carpeta_salida = os.path.join(output_folder, fecha_carpeta)
        os.makedirs(carpeta_salida, exist_ok=True)  # Crear carpeta si no existe

        escritor_pdf = PdfWriter()
        for pagina_num in datos["paginas"]:
            escritor_pdf.add_page(lector_pdf.pages[pagina_num])

        ruta_guardado = os.path.join(carpeta_salida, f"{albaran}.pdf")
        with open(ruta_guardado, "wb") as archivo_salida:
            escritor_pdf.write(archivo_salida)

    print(f"Albaranes found: {albaranes}")
    print(f"Output directory: {carpeta_fecha}")
    print(f"PDF file exists: {os.path.exists(pdf_path)}")
    return carpeta_fecha


# Ejemplo de uso:
pdf_path = "/content/PDFs_divididos/Binder2.pdf"  # Ruta del PDF en Google Colab
output_folder = "/content/PDFs_divididos"  # Carpeta de salida en Google Colab
# Get the value of carpeta_fecha by calling the function
carpeta_fecha = dividir_pdf_por_albaran(pdf_path, output_folder)

# Crear un archivo zip de la carpeta y descargarlo
# Use carpeta_fecha, which is now available outside the function
shutil.make_archive("PDFs_divididos", 'zip', carpeta_fecha)
files.download("PDFs_divididos.zip")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.6).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-spa is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# ...

# %%
# !apt-get install poppler-utils # Install poppler-utils, which includes pdfinfo
# !pip install pytesseract pdf2image PyPDF2
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev
# !sudo apt install tesseract-ocr-spa # Install Spanish language data

import pytesseract
from PIL import Image, ImageEnhance # Import ImageEnhance for contrast adjustment
import io
from pdf2image import convert_from_path
import os
import datetime
import re # Import re module here
from PyPDF2 import PdfWriter, PdfReader
import shutil # import the shutil module
from google.colab import files # import the files object from google.colab


# Configurar la ruta a Tesseract OCR en Google Colab
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

def dividir_pdf_por_albaran(pdf_path, output_folder):
    # Convertir PDF a imágenes
    imagenes = convert_from_path(pdf_path)

    albaranes = {}

    for i, imagen in enumerate(imagenes):
        # Image Preprocessing (Enhance Contrast)
        enhancer = ImageEnhance.Contrast(imagen)
        imagen_enhanced = enhancer.enhance(2.0)  # Adjust the factor as needed

        # OCR with PSM option
        texto = pytesseract.image_to_string(imagen_enhanced, lang='spa', config='--psm 6') # Experiment with different PSM values

        # 1. Extraer el número de Albarán y la Fecha Registro
        match_albaran = re.search(r"(V-ALB\d{6})", texto)
        match_fecha = re.search(r"(\d{2}/\d{2}/\d{4})", texto)

        if match_albaran and match_fecha:
            numero_albaran = match_albaran.group(1)
            fecha_registro = match_fecha.group(1).replace("/", "-")

            # Almacenar el número de Albarán y la fecha de registro
            if numero_albaran not in albaranes:
                albaranes[numero_albaran] = {"fecha_registro": fecha_registro, "paginas": []}
            albaranes[numero_albaran]["paginas"].append(i)

    # Crear PDFs individuales en carpetas separadas por fecha
    lector_pdf = PdfReader(pdf_path)
    for albaran, datos in albaranes.items():
        fecha_carpeta = datos["fecha_registro"]
        carpeta_salida = os.path.join(output_folder, fecha_carpeta)
        os.makedirs(carpeta_salida, exist_ok=True)  # Crear carpeta si no existe

        escritor_pdf = PdfWriter()
        for pagina_num in datos["paginas"]:
            escritor_pdf.add_page(lector_pdf.pages[pagina_num])

        ruta_guardado = os.path.join(carpeta_salida, f"{albaran}.pdf")
        with open(ruta_guardado, "wb") as archivo_salida:
            escritor_pdf.write(archivo_salida)

    print(f"Albaranes found: {albaranes}")
    # Assuming 'carpeta_fecha' is meant to be 'carpeta_salida' or a similar variable
    # since 'carpeta_fecha' is not consistently defined within this function
    print(f"Output directory: {carpeta_salida}")
    print(f"PDF file exists: {os.path.exists(pdf_path)}")
    return carpeta_salida  # Return a relevant output directory


# Ejemplo de uso:
pdf_path = "/content/PDFs_divididos/Binder2.pdf"  # Ruta del PDF en Google Colab
output_folder = "/content/PDFs_divididos"  # Carpeta de salida en Google Colab
# Get the value of carpeta_fecha by calling the function
carpeta_fecha = dividir_pdf_por_albaran(pdf_path, output_folder)

# Crear un archivo zip de la carpeta y descargarlo
# Use carpeta_fecha, which is now available outside the function
shutil.make_archive("PDFs_divididos", 'zip', carpeta_fecha)
files.download("PDFs_divididos.zip")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.6).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-spa is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# ...

# %%
# !apt-get install poppler-utils # Install poppler-utils, which includes pdfinfo
# !pip install pytesseract pdf2image PyPDF2
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev
# !sudo apt install tesseract-ocr-spa # Install Spanish language data

import pytesseract
from PIL import Image, ImageEnhance # Import ImageEnhance for contrast adjustment
import io
from pdf2image import convert_from_path
import os
import datetime
import re # Import re module here
from PyPDF2 import PdfWriter, PdfReader
import shutil # import the shutil module
from google.colab import files # import the files object from google.colab


# Configurar la ruta a Tesseract OCR en Google Colab
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

def dividir_pdf_por_albaran(pdf_path, output_folder):
    # Convertir PDF a imágenes
    imagenes = convert_from_path(pdf_path)

    albaranes = {}

    for i, imagen in enumerate(imagenes):
        # Image Preprocessing (Enhance Contrast)
        enhancer = ImageEnhance.Contrast(imagen)
        imagen_enhanced = enhancer.enhance(2.0)  # Adjust the factor as needed

        # OCR with PSM option
        texto = pytesseract.image_to_string(imagen_enhanced, lang='spa', config='--psm 6') # Experiment with different PSM values

        # 1. Extraer el número de Albarán y la Fecha Registro
        match_albaran = re.search(r"(V-ALB\d{6})", texto)
        match_fecha = re.search(r"(\d{2}/\d{2}/\d{4})", texto)

        if match_albaran and match_fecha:
            numero_albaran = match_albaran.group(1)
            fecha_registro = match_fecha.group(1).replace("/", "-")

            # Almacenar el número de Albarán y la fecha de registro
            if numero_albaran not in albaranes:
                albaranes[numero_albaran] = {"fecha_registro": fecha_registro, "paginas": []}
            albaranes[numero_albaran]["paginas"].append(i)

    # Crear PDFs individuales en carpetas separadas por fecha
    lector_pdf = PdfReader(pdf_path)
    for albaran, datos in albaranes.items():
        fecha_carpeta = datos["fecha_registro"]
        carpeta_salida = os.path.join(output_folder, fecha_carpeta)
        os.makedirs(carpeta_salida, exist_ok=True)  # Crear carpeta si no existe

        escritor_pdf = PdfWriter()
        for pagina_num in datos["paginas"]:
            escritor_pdf.add_page(lector_pdf.pages[pagina_num])

        ruta_guardado = os.path.join(carpeta_salida, f"{albaran}.pdf")
        with open(ruta_guardado, "wb") as archivo_salida:
            escritor_pdf.write(archivo_salida)

    print(f"Albaranes found: {albaranes}")
    print(f"Output directory: {carpeta_salida}")
    print(f"PDF file exists: {os.path.exists(pdf_path)}")
    return output_folder  # Return the main output folder



# Ejemplo de uso:
pdf_path = "/content/PDFs_divididos/Binder2.pdf"  # Ruta del PDF en Google Colab
output_folder = "/content/PDFs_divididos"  # Carpeta de salida en Google Colab
# Get the value of carpeta_fecha by calling the function
carpeta_fecha = dividir_pdf_por_albaran(pdf_path, output_folder)

# Crear un archivo zip de la carpeta y descargarlo
# Now archiving the entire output_folder
shutil.make_archive("PDFs_divididos", 'zip', output_folder)
files.download("PDFs_divididos.zip")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.6).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-spa is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# ...

# %% [markdown]
# Codigo perfecto para la nube, falta mejorar el archivo de descarga
